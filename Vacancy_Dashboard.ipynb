# %% [markdown]
# <a href="https://colab.research.google.com/github/Macdaline100/PythonDataScienceHandbook/blob/master/Vacancy_Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vacancy Dashboard
#
# <div align="center" style="width: 800px; font-size: 100%; text-align: center; margin: 0 auto">
# <img src=""
#
# </div>

# %% [markdown]
# ![recommender.png](data:image/png;base64,...)
